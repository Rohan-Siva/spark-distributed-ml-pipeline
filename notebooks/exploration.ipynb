# %% [markdown]
# # Data Exploration
#
# This notebook demonstrates how to load and explore data using the `DataLoader` class.

# %%
import sys
import os

sys.path.append(os.path.abspath('../'))

from src.data_loader import DataLoader
from src.spark_utils import get_spark_session

# %%
spark = get_spark_session(app_name="Exploration")
loader = DataLoader(spark)

# %%
df = loader.generate_synthetic_data(num_rows=1000, num_features=5)
df.show(5)

# %%
df.describe().show()
